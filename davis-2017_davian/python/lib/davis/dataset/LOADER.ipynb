# %% [markdown]
# # DAVISLoader phase
# TRAIN    = 'train'
# VAL      = 'val'
# TESTDEV  = 'test-dev'
# TRAINVAL = 'train-val'

# %%
from loader import DAVISLoader

# %%
test_dataset = DAVISLoader(year='2017', phase='test-dev')

# %%
test_dataset[0]
# Out:
# {'images': <base.Sequence at 0x7fae3b6efcc0>,
#  'annotations': <base.Annotation at 0x7fae3b9a3f98>}

# %% [markdown]
# ### annotation은 images의 첫번째 프레임에 대해서만 존재
# #### >>> test_dataset[0]['images'][0],test_dataset[0]['annotations'][0] 만 사용해야함
# test_dataset[0]['images'][0], test_dataset[0]['images'][1], test_dataset[0]['images'][2]...하게 존재해도 annotation은 0에 대해서만 존재

# %%
# %matplotlib inline
from matplotlib import pyplot as plt
plt.imshow(test_dataset[0]['images'][0])
plt.show()

# %%
# %matplotlib inline
from matplotlib import pyplot as plt
plt.imshow(test_dataset[0]['annotations'][0])
plt.show()

# %% [markdown]
# ### 이 프레임에 대해서는 annotation 없음

# %%
# %matplotlib inline
from matplotlib import pyplot as plt
plt.imshow(test_dataset[0]['images'][50])
plt.show()
